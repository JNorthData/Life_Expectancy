# %%
import pandas as pd

Number_Deaths_df = pd.read_csv('Resources/OWID number-of-deaths-by-risk-factor.csv')

Mean_BMI_df = pd.read_csv('Resources/WHO Mean BMI (kg:m2).csv')

Mean_BMI_df = pd.read_csv('Resources/WHO Mean BMI (kg:m2).csv')

# %%
Number_Deaths_df
# Out:
#           Country  Year  Outdoor Air Pollution  Alcohol Use  \
# 0     Afghanistan  1990                   3169          356
# 1     Afghanistan  1991                   3222          364
# 2     Afghanistan  1992                   3395          376
# 3     Afghanistan  1993                   3623          389
# 4     Afghanistan  1994                   3788          399
# ...           ...   ...                    ...          ...
# 6835     Zimbabwe  2015                   2835         4854
# 6836     Zimbabwe  2016                   2781         4915
# 6837     Zimbabwe  2017                   2700         4992
# 6838     Zimbabwe  2018                   2669         5044
# 6839     Zimbabwe  2019                   2680         5156
#
#       Second Hand Smoke  Household Air Pollution  Low Physical Activity  \
# 0                  4794                    34372                   2637
# 1                  4921                    35392                   2652
# ...

# %%
Mean_BMI_df
# Out:
#            Country  Year         Sex  Average BMI
# 0         Ethiopia  2016        Male         20.1
# 1          Eritrea  2016        Male         20.2
# 2         Ethiopia  2016  Both sexes         20.6
# 3          Eritrea  2016  Both sexes         20.7
# 4       Madagascar  2016      Female         21.1
# ...            ...   ...         ...          ...
# 24565  South Sudan  1975      Female          NaN
# 24566  South Sudan  1975        Male          NaN
# 24567        Sudan  1975  Both sexes          NaN
# 24568        Sudan  1975      Female          NaN
# 24569        Sudan  1975        Male          NaN
#
# [24570 rows x 4 columns]
